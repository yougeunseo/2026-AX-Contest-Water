# %%
import pandas as pd
print("판다스 준비 완료!")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\min\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\min\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
# !pip install --upgrade --force-reinstall numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.3 MB 11.2 MB/s eta 0:00:01
#    --------------- ------------------------ 4.7/12.3 MB 11.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.3 MB 11.3 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.3 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 11.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\min\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\min\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\min\anaconda3\Lib\site-packages)
# ...

# %%
# !pip install "numpy<2"
# Out:
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/15.5 MB 11.8 MB/s eta 0:00:02
#    ------------ --------------------------- 4.7/15.5 MB 11.4 MB/s eta 0:00:01
#    ------------------ --------------------- 7.1/15.5 MB 11.5 MB/s eta 0:00:01
#    ------------------------- -------------- 9.7/15.5 MB 11.6 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.5 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 11.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\min\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\min\anaconda3\Lib\site-packages)
# ...

# %%
import pandas as pd
print("판다스 준비 완료!")
# Out:
# 판다스 준비 완료!
